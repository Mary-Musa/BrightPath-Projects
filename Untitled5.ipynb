# %% [markdown]
# <a href="https://colab.research.google.com/github/Mary-Musa/BrightPath-Projects/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#TASK 2.1
from tensorflow.keras.preprocessing.text import Tokenizer

# !wget http://www.gutenberg.org/files/100/100-0.txt
filePath = "/content/100-0.txt"
ShakespeareFile = open(filePath, "r")
ShakespeareContent = ShakespeareFile.read()
ShakespeareContent = ShakespeareContent.splitlines() # The splitlines() method splits a string into a list. The splitting is done at line breaks.
print(f'list of first 50 lines: {ShakespeareContent[0:50]}')

tokenizer = Tokenizer(num_words = 100)
tokenizer.fit_on_texts(ShakespeareContent)

total_tokens = sum(tokenizer.word_counts.values())
print("the total number of tokens:", total_tokens)
print("the total number of types:",len(tokenizer.word_index))
print("the most common word", tokenizer.index_word[1])
# Out:
# URL transformed to HTTPS due to an HSTS policy
# --2026-09-24 07:19:34--  https://www.gutenberg.org/files/100/100-0.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5422721 (5.2M) [text/plain]
# Saving to: ‘100-0.txt.7’
#
# 100-0.txt.7         100%[===================>]   5.17M  15.9MB/s    in 0.3s
#
# 2026-09-24 07:19:35 (15.9 MB/s) - ‘100-0.txt.7’ saved [5422721/5422721]
#
# ...

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

words = ["connected", "connecting", "connection", "connects"]

for w in words:
  print(w, "->", stemmer.stem(w))


print()


words = ["played", "playing", "plays"]
for w in words:
    print(w, "->",stemmer.stem(w))
# Out:
# connected -> connect
# connecting -> connect
# connection -> connect
# connects -> connect
#
# played -> play
# playing -> play
# plays -> play

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

words = ["running", "studies", "ran", "better"]

for w in words:
  print(w, "->", lemmatizer.lemmatize(w, pos="v"))

  print()


words = ["geese", "children", "feet", "leaves", "cars"]

for w in words:
  print(w, "->",lemmatizer.lemmatize(w))
# Out:
# running -> run
#
# studies -> study
#
# ran -> run
#
# better -> better
#
# geese -> goose
# children -> child
# feet -> foot
# leaves -> leaf
# cars -> car

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

words = ["was", "eating", "wrote", "going", "flies"]

for w in words:

   print(w, "->", lemmatizer.lemmatize(w, pos="v"))


print(lemmatizer.lemmatize("better",pos="a"))
print(lemmatizer.lemmatize("better"))
# Out:
# was -> be
# eating -> eat
# wrote -> write
# going -> go
# flies -> fly
# good
# better

# %%
#compare stemming and lemmatization on the same list of words

words = ["running", "studies", "ran", "better"]

print(w,"| stemmer",stemmer.stem(w), "| lemma",lemmatizer.lemmatize(w,pos="v"))
# Out:
# flies | stemmer fli | lemma fly

# %%
#Sentence segmentation which is same as sentence tokenization

from nltk.tokenize import sent_tokenize

text = "Natural Language Processing is exciting. Machines can read text. Can they understand it? Researchers are still working on that."

sentences = sent_tokenize(text)

print(sentences)

print("Number of sentences:", len(sentences))
# Out:
# ['Natural Language Processing is exciting.', 'Machines can read text.', 'Can they understand it?', 'Researchers are still working on that.']
# Number of sentences: 4

# %% [markdown]
# Segment the Shakespeare corpus into sentences. Print the total number of sentences and the first 5 sentences

# %%
from nltk.tokenize import sent_tokenize
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
from nltk.tokenize import sent_tokenize

text = open("/content/100-0.txt", encoding="utf-8").read()

sentences = sent_tokenize(text)

print("Total number of sentences:", len(sentences))
print(sentences[0:5])
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Total number of sentences: 104698
# ...
